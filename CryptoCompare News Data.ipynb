# %%
import cryptocompare
import requests

# %%
apiKey = "49cb3bc443bbff0927d23d75aea8501b3242af2cbb44b0a5130f72046bc6819d"

url = "https://min-api.cryptocompare.com/data/v2/news/"

payload = {
    "lang":"EN",
}

headers = {
    "authorization": 'ApiKey' + apiKey
}

result = requests.get(url, headers=headers, params=payload).json()
result['Data']
# Out:
# [{'id': '26008591',
#   'guid': 'https://decrypt.co/?p=51311',
#   'published_on': 1607873782,
#   'imageurl': 'https://images.cryptocompare.com/news/decrypt/8tUu8tae8t3.jpeg',
#   'title': 'Host of CNBC’s ‘Mad Money’ Explains Why He Invested in Bitcoin',
#   'url': 'https://decrypt.co/51311/host-of-cnbcs-mad-money-explains-why-he-invested-in-bitcoin',
#   'source': 'decrypt',
#   'body': "The founder of TheStreet and host of CNBC's 'Mad Money' has invested in Bitcoin.",
#   'tags': 'Business|BTC',
#   'categories': 'BTC|Business',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Decrypt',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/decrypt.png'}},
#  {'id': '26008421',
#   'guid': 'http://ambcrypto.com/?p=131175',
#   'published_on': 1607873430,
#   'imageurl': 'https://images.cryptocompare.com/news/ambcrypto/acbS1HirIc0.jpeg',
#   'title': 'New withdrawal mechanism for ETH2 stakes ‘under discussion’',
#   'url': 'https://ambcrypto.com/new-withdrawal-mechanism-for-eth2-stakes-under-discussion/',
#   'source': 'ambcrypto',
#   'body': 'Almost 2 weeks after Ethereum 2.0 beacon chain went live, over 1.4 million ETH have been staked on the deposit contract, with 31,000 active validators and 13,000 in the activation queue. While the ensuing period since hasn&#8217;t been too development-heavy, according to some like\xa0developer Ben Edgington, ‘no news’ is good news. &#8220;It’s been a wonderfully [&#8230;]',
#   'tags': 'Ethereum|News 1|Social|Trading View|Ben Edgington|ETH 2',
#   'categories': 'ETH',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'AMB Crypto',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/ambcrypto.png'}},
#  {'id': '26008128',
#   'guid': 'https://cryptopotato.com/?p=94458',
#   'published_on': 1607872564,
#   'imageurl': 'https://images.cryptocompare.com/news/cryptopotato/946Jy1A2kA0.jpeg',
#   'title': 'Today Marks 10 Years Since Satoshi Nakamoto’s Last Public Activity',
#   'url': 'https://cryptopotato.com/today-marks-10-years-since-satoshi-nakamotos-last-public-activity/',
#   'source': 'cryptopotato',
#   'body': "Today is somewhat of a special day because it marks exactly ten years since Satoshi Nakamoto's last public activity.",
#   'tags': 'BTCEUR|BTCGBP|BTCUSD|BTCUSDT|Crypto News|featured1|social|Bitcoin|Satoshi Nakamoto',
#   'categories': 'BTC',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Crypto Potato',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cryptopotato.png'}},
#  {'id': '26007747',
#   'guid': 'https://decrypt.co/?p=51305',
#   'published_on': 1607871291,
#   'imageurl': 'https://images.cryptocompare.com/news/decrypt/b0MoIi138h0.jpeg',
#   'title': 'XRP’s Price Steadies After Crash That Followed Huge Airdrop',
#   'url': 'https://decrypt.co/51305/xrps-price-steadies-after-crash-that-followed-huge-airdrop',
#   'source': 'decrypt',
#   'body': 'XRP’s price crashed after a massive airdrop gave free crypto to XRP holders who held funds in participating exchanges and wallets. Now, it’s on the up.',
#   'tags': 'Coins|XRP',
#   'categories': 'XRP|Trading',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Decrypt',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/decrypt.png'}},
#  {'id': '26007621',
#   'guid': 'https://cointelegraph.com/news/publicly-recanted-luminaries-who-came-to-terms-with-crypto-in-2020',
#   'published_on': 1607870820,
#   'imageurl': 'https://images.cryptocompare.com/news/cointelegraph/f1wj5i0c080.jpeg',
#   'title': 'Publicly recanted! Luminaries who came to terms with crypto in 2020',
#   'url': 'https://cointelegraph.com/news/publicly-recanted-luminaries-who-came-to-terms-with-crypto-in-2020',
#   'source': 'cointelegraph',
#   'body': 'Bitcoin may never be a widely used medium of exchange, but it has become a useful store of value, former critics concede in 2020.',
#   'tags': "New Year's Special|Coronavirus|PayPal",
#   'categories': 'BTC|Exchange',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'CoinTelegraph',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cointelegraph.png'}},
#  {'id': '26007210',
#   'guid': 'http://ambcrypto.com/?p=131105',
#   'published_on': 1607869850,
#   'imageurl': 'https://images.cryptocompare.com/news/ambcrypto/fkUw8200000.jpeg',
#   'title': 'Bitcoin: Retail v. whale traders and who profited the most?',
#   'url': 'https://ambcrypto.com/bitcoin-retail-v-whale-traders-and-who-profited-the-most/',
#   'source': 'ambcrypto',
#   'body': 'Bitcoin&#8217;s last 2 quarters in 2020 have been quite volatile. Rather, that has been the case for most of 2020. In fact, each quarter had something important like the Pandemic-induced crash in Q1, the V-shaped recovery in Q2, the institutional buying in Q3, followed by the rapid explosion in price in Q4. While institutions have [&#8230;]',
#   'tags': 'Bitcoin|BTC Trading View|News 1|Social|Trading View',
#   'categories': 'BTC|Trading',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'AMB Crypto',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/ambcrypto.png'}},
#  {'id': '26007179',
#   'guid': 'https://decrypt.co/?p=51297',
#   'published_on': 1607869460,
#   'imageurl': 'https://images.cryptocompare.com/news/decrypt/c0vocgXsA1H.jpeg',
#   'title': 'The 10 Year Anniversary of Bitcoin Creator’s Disappearance',
#   'url': 'https://decrypt.co/51297/the-10-year-anniversary-of-bitcoin-creators-disappearance',
#   'source': 'decrypt',
#   'body': '10 years ago today, Bitcoin’s anonymous creator, Satoshi Nakamoto, was last active online. No one knows what he’s been up to since.',
#   'tags': 'Business|BTC',
#   'categories': 'BTC|Business',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Decrypt',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/decrypt.png'}},
#  {'id': '26007066',
#   'guid': 'https://www.cryptopolitan.com/?p=74627',
#   'published_on': 1607869205,
#   'imageurl': 'https://images.cryptocompare.com/news/cryptopolitan/8Assy4JV3dC.jpeg',
#   'title': 'Buy Bitcoin, Robert Kiyosaki urges',
#   'url': 'https://www.cryptopolitan.com/buy-bitcoin-robert-kiyosaki-urges/',
#   'source': 'cryptopolitan',
#   'body': 'Popular author urges his Twitter followers to buy Bitcoin Says he is happy to have invested in the crypto asset Robert Kiyosaki, author of the popular financial masterpiece “Rich Dad Poor Dad” urged his followers on Twitter to buy Bitcoin, after expressing that he was happy to have bought the crypto asset. The author went […]',
#   'tags': 'Bitcoin News',
#   'categories': 'BTC',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Cryptopolitan',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cryptopolitan.png'}},
#  {'id': '26006829',
#   'guid': 'https://www.trustnodes.com/?p=34288',
#   'published_on': 1607868561,
#   'imageurl': 'https://images.cryptocompare.com/news/trustnodes/a0000000000.png',
#   'title': 'India Surpasses China in Peer to Peer Bitcoin Volumes',
#   'url': 'https://www.trustnodes.com/2020/12/13/india-surpasses-china-in-peer-to-peer-bitcoin-volumes',
#   'source': 'trustnodes',
#   'body': 'India is rising as a bitcoin hot spot after their Supreme Court overturned a central bank diktat, opening the way for the second most populous country on earth to join...',
#   'tags': 'Bitcoin|News',
#   'categories': 'BTC|Asia|Fiat',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'TrustNodes',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/trustnodes.png'}},
#  {'id': '26006784',
#   'guid': 'https://en.ethereumworldnews.com/?p=564979',
#   'published_on': 1607868377,
#   'imageurl': 'https://images.cryptocompare.com/news/ethereumworldnews/ai2CF0Fgwkp.jpeg',
#   'title': '10.7% of Ethereum 2.0 Validator Deposits are From Kraken',
#   'url': 'https://en.ethereumworldnews.com/10-7-of-ethereum-2-0-validator-deposits-are-from-kraken/',
#   'source': 'ethereumworldnews',
#   'body': 'Quick take: 10.7% of Ethereum 2.0 validator deposits are from Kraken Coinbase and Bitfinex hold 5.8x more Ethereum than Kraken 2 crypto exchange could control 1/3 of the validators, 5 exchanges could control 1/2 of the validators 1.436 Million ETH is locked in the deposit contract with more being sent daily 10.7% of the current Ethereum 2.0 validator deposits are from the crypto exchange of Kraken. This is according to ETH2.0 researcher Justin Drake, who further pointed out that Coinbase [&#8230;]',
#   'tags': 'Ethereum (ETH) News|DeFi|Binance|coinbase|Ethereum (ETH)|Ethereum Upgrade|Kraken',
#   'categories': 'ETH|Exchange',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Ethereum World News',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/ethereumworldnews.png'}},
#  {'id': '26006764',
#   'guid': 'https://www.coindesk.com/index.php?p=554221',
#   'published_on': 1607868000,
#   'imageurl': 'https://images.cryptocompare.com/news/coindesk/a72wy0g0028.jpeg',
#   'title': 'How Much Debt Can a Country Handle?',
#   'url': 'https://www.coindesk.com/how-much-debt-can-a-country-handle',
#   'source': 'coindesk',
#   'body': 'As conventional wisdom grows that central banks can go more deeply into debt than previously thought, one economist asks, how much is too much?',
#   'tags': 'People|Debt|Podcasts|The Breakdown',
#   'categories': 'Other',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'CoinDesk',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/coindesk.png'}},
#  {'id': '26006707',
#   'guid': 'https://www.cryptoglobe.com/latest/2020/12/bitcoin-up-9-85-since-friday-rich-dad-author-says-buy-below-20-k/',
#   'published_on': 1607867849,
#   'imageurl': 'https://images.cryptocompare.com/news/cryptoglobe/c2g6$PM0weM.png',
#   'title': 'Bitcoin Up 9.85% Since Friday, ‘Rich Dad Author’ Says ‘Buy Below $20 K’',
#   'url': 'https://www.cryptoglobe.com/latest/2020/12/bitcoin-up-9-85-since-friday-rich-dad-author-says-buy-below-20-k/',
#   'source': 'cryptoglobe',
#   'body': 'Bitcoin has had a pretty great weekend so far, up almost 10% since Friday’s intraday low. According to data by CryptoCompare, on Friday, around 17:00 UTC, Bitcoin reached the intraday low of $17,598. Currently (as of 13:38 UTC on December 13), BTS-USD is trading at $19,331, which means that the Bitcoin price has gone by […]',
#   'tags': 'Bitcoin',
#   'categories': 'BTC|Trading',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'CryptoGlobe',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cryptoglobe.png'}},
#  {'id': '26006557',
#   'guid': 'https://dailyhodl.com/?p=121509',
#   'published_on': 1607867727,
#   'imageurl': 'https://images.cryptocompare.com/news/dailyhodl/dii0jwU930M.jpeg',
#   'title': 'PlanB Says Bitcoin Entering Enormous Bull Year in 2021, Outlines Price Targets and Biggest Risk to BTC',
#   'url': 'https://dailyhodl.com/2020/12/13/planb-says-bitcoin-entering-enormous-bull-year-in-2021-outlines-price-targets-and-biggest-risk-to-btc/',
#   'source': 'dailyhodl',
#   'body': 'Institutional quantitative investor and creator of the BTC stock-to-flow valuation model PlanB says Bitcoin&#8217;s unique scarcity is setting up the leading cryptocurrency to surge in 2021. In a new interview with SALT Talks, PlanB advertises a bullish 2021 ride for the leading cryptocurrency. The experienced Dutch analyst hypothesizes that Bitcoin&#8217;s value can skyrocket to $300,000 [&#8230;]The post PlanB Says Bitcoin Entering Enormous Bull Year in 2021, Outlines Price Targets and Biggest Risk to BTC appeared first on The Daily Hodl.',
#   'tags': 'Bitcoin|Regulators|BTC|News|regulation',
#   'categories': 'BTC|Trading|Regulation|Business',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'The Daily Hodl',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/dailyhodl.png'}},
#  {'id': '26006360',
#   'guid': 'https://zycrypto.com/?p=47334',
#   'published_on': 1607867043,
#   'imageurl': 'https://images.cryptocompare.com/news/zycrypto/9m0401G0600.jpeg',
#   'title': 'Bitcoin Gains Popularity Among The Rich As Bull Market Rages On',
#   'url': 'https://zycrypto.com/bitcoin-gains-popularity-among-the-rich-as-bull-market-rages-on/',
#   'source': 'zycrypto',
#   'body': 'More wealthy mainstream investors are getting attracted to the cryptocurrency space. This is particularly true for the number one cryptocurrency, Bitcoin. At the moment, Bitcoin has gained 270% since March this year. This is a huge return on investment that has left many top mainstream investors wondering if it is wise to continue standing on [&#8230;]',
#   'tags': 'Bitcoin|News|Bitcoin News|BTCUSD|BTCUSDC|BTCUSDT|XBTUSD',
#   'categories': 'BTC|Business|Market|Trading',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'ZyCrypto',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/zycrypto.png'}},
#  {'id': '26006151',
#   'guid': 'https://cryptopotato.com/?p=93946',
#   'published_on': 1607866663,
#   'imageurl': 'https://images.cryptocompare.com/news/cryptopotato/d30i2y00808.jpeg',
#   'title': 'Room For Growth? Only 10% of UK Citizens Have Purchased Bitcoin',
#   'url': 'https://cryptopotato.com/room-for-growth-only-10-of-uk-citizens-have-purchased-bitcoin/',
#   'source': 'cryptopotato',
#   'body': 'Only 10% of UK citizens have bought BTC but the asset is largely popular in London as one in four residents have purchased it, survey says.',
#   'tags': 'AA News|BTCEUR|BTCGBP|BTCUSD|BTCUSDT|Crypto News|social|Bitcoin|Gold|United Kingdom',
#   'categories': 'BTC|Fiat',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Crypto Potato',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cryptopotato.png'}},
#  {'id': '26005869',
#   'guid': 'https://cointelegraph.com/news/bitcoin-price-suddenly-regains-bullish-momentum-with-20k-in-sight',
#   'published_on': 1607865637,
#   'imageurl': 'https://images.cryptocompare.com/news/cointelegraph/98JO6Fbc3mR.jpeg',
#   'title': 'Bitcoin price suddenly regains bullish momentum with $20K in sight',
#   'url': 'https://cointelegraph.com/news/bitcoin-price-suddenly-regains-bullish-momentum-with-20k-in-sight',
#   'source': 'cointelegraph',
#   'body': 'The price of Bitcoin has broken through crucial resistance in weekend trading. ',
#   'tags': 'Bitcoin price|technical analysis|price analysis|btc price',
#   'categories': 'Trading|BTC',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'CoinTelegraph',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cointelegraph.png'}},
#  {'id': '26005861',
#   'guid': 'https://www.cryptoglobe.com/latest/2020/12/former-goldman-sachs-exec-on-muti-trillion-dollar-opportunities-for-crypto/',
#   'published_on': 1607865561,
#   'imageurl': 'https://images.cryptocompare.com/news/cryptoglobe/ezp1m17980i.jpeg',
#   'title': 'Former Goldman Sachs Exec on Muti-Trillion Dollar Opportunities for Crypto',
#   'url': 'https://www.cryptoglobe.com/latest/2020/12/former-goldman-sachs-exec-on-muti-trillion-dollar-opportunities-for-crypto/',
#   'source': 'cryptoglobe',
#   'body': 'On Friday (December 11), former hedge fund manager Raoul Pal talked about the multi-trillion dollar opportunities that exist in traditional financial markets for Bitcoin and Ethereum. Prior to founding macro economic and investment strategy research service\xa0Global Macro Investor (GMI)\xa0in 2005, Pal\xa0co-managed the GLG Global Macro Fund in London for global asset management firm GLG Partners […]',
#   'tags': 'Altcoins|Bitcoin',
#   'categories': 'BTC|Fiat|ETH|Market|Altcoin',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'CryptoGlobe',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cryptoglobe.png'}},
#  {'id': '26005431',
#   'guid': 'http://ambcrypto.com/?p=131123',
#   'published_on': 1607864402,
#   'imageurl': 'https://images.cryptocompare.com/news/ambcrypto/cgP4i0ww220.jpeg',
#   'title': 'Bitcoin SV, IOTA, Nano Price Analysis: 13 December',
#   'url': 'https://ambcrypto.com/bitcoin-sv-iota-nano-price-analysis-13-december/',
#   'source': 'ambcrypto',
#   'body': 'Bitcoin SV recovered somewhat following the gains Bitcoin posted over the past couple of days, with BSV approaching its level of resistance on the charts. IOTA was trading just above its level of support, and a rise past $0.3 signaled that a test of $0.326 was imminent. Nano gave a bullish signal and posted some [&#8230;]',
#   'tags': 'Altcoins|Analysis|HideCryptopanic|News 1|Social|Trading View|BSV|IOTA|NANO',
#   'categories': 'BTC|Trading|Market|Altcoin',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'AMB Crypto',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/ambcrypto.png'}},
#  {'id': '26005262',
#   'guid': 'https://en.ethereumworldnews.com/?p=564972',
#   'published_on': 1607863916,
#   'imageurl': 'https://images.cryptocompare.com/news/ethereumworldnews/9aQFgOii00g.jpeg',
#   'title': 'DeFi Could Break $20B in Total Value Locked before EOY – Report',
#   'url': 'https://en.ethereumworldnews.com/defi-could-break-20b-in-total-value-locked-before-eoy-report/',
#   'source': 'ethereumworldnews',
#   'body': 'Quick summary: Total Value Locked in DeFi recently breached $15B before dipping back to$14B levels The current total value locked stands at $14.66 Billion DeFi&#8217;s total value locked has a chance at breaching $20B before year&#8217;s end DeFi tokens are also posting impressive triple-digit gains and high trade volume The total value locked in DeFi recently reached a new milestone of $15 Billion on Monday, December 7th. The total value locked went on to peak at $15.038 Billion before dropping [&#8230;]',
#   'tags': 'DeFi|Ethereum (ETH) News|defi|DeFi Pulse|Ethereum (ETH)',
#   'categories': 'ICO',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Ethereum World News',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/ethereumworldnews.png'}},
#  {'id': '26004812',
#   'guid': 'http://ambcrypto.com/?p=131142',
#   'published_on': 1607862657,
#   'imageurl': 'https://images.cryptocompare.com/news/ambcrypto/c00woco0S0g.jpeg',
#   'title': 'Bitcoin price analysis: 13 December',
#   'url': 'https://ambcrypto.com/bitcoin-price-analysis-13-december/',
#   'source': 'ambcrypto',
#   'body': 'Disclaimer:\xa0The findings of the following article are the sole opinion of the writer and should not be taken as investment advice Bitcoin, the world&#8217;s largest cryptocurrency, was hovering in the $17,000-range 24-hours ago. However, the price did seem to have appreciated considerably since. At press time, Bitcoin looked toppy, with its price recorded to be [&#8230;]',
#   'tags': 'Analysis|Bitcoin|BTC Trading View|HideCryptopanic|News 1|Social|Trading View|Bitcoin price prediction',
#   'categories': 'BTC|Trading|Market',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'AMB Crypto',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/ambcrypto.png'}},
#  {'id': '26004857',
#   'guid': 'https://news.bitcoin.com/?p=428963',
#   'published_on': 1607862630,
#   'imageurl': 'https://images.cryptocompare.com/news/bitcoin.com/99Ai4FaiQw0.jpeg',
#   'title': 'Ledger Wallet Customer Data Leak Invokes Threats, Phishing Scams, User Allegedly Loses Life Savings',
#   'url': 'https://news.bitcoin.com/ledger-wallet-customer-data-leak-invokes-threats-phishing-scams-user-allegedly-loses-life-savings/',
#   'source': 'bitcoin.com',
#   'body': 'The cryptocurrency hardware wallet firm Ledger was hacked last June and over a million emails were exposed, according to reports from the company at the time. Months later, the hackers who obtained the Ledger data emailed clients, sent texts to customers, and created phishing links for users to enter their seeds. One customer allegedly lost [&#8230;]The post Ledger Wallet Customer Data Leak Invokes Threats, Phishing Scams, User Allegedly Loses Life Savings appeared first on Bitcoin News.',
#   'tags': 'Security|Andreas Antonopolous|Bitcoin|Bitcoin (BTC)|Brad Mills|Crypto|Cryptocurrency|Data Breach|emails|Ledger|Ledger Hardware Wallet|Ledger Wallet|Losing funds|million customer|Passphrase|Phishing emails|Reddit Community|Seed|SMS|Text Messages|Trezor|Twitter',
#   'categories': 'Wallet|BTC',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Bitcoin.com',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/bitcoincom.png'}},
#  {'id': '26004643',
#   'guid': 'https://en.ethereumworldnews.com/?p=564969',
#   'published_on': 1607862131,
#   'imageurl': 'https://images.cryptocompare.com/news/ethereumworldnews/9m7qURYJCen.jpeg',
#   'title': 'Buy Bitcoin (BTC) Below $20k – Rich Dad Poor Dad Author',
#   'url': 'https://en.ethereumworldnews.com/buy-bitcoin-btc-below-20k-rich-dad-poor-dad-author/',
#   'source': 'ethereumworldnews',
#   'body': 'In summary: Robert Kiyosaki has pointed out that buying Bitcoin below $20k might be a good idea Mr. Kiyosaki forecasts that Bitcoin will hit $50k soon He explains that institutional money is buying up the BTC in the markets The American economy is in trouble and the future is in Gold, Silver, Bitcoin and Entrepreneurs Bitcoin has refused to dip below $17k and is once again above $19k The author of &#8216;Rich Dad Poor Dad&#8217;, Robert Kiyosaki, has expressed via [&#8230;]',
#   'tags': 'Bitcoin (BTC) News|Bitcoin (BTC) Adoption|Bitcoin (BTC) General News|Bitcoin (BTC) Predictions',
#   'categories': 'BTC|Market|Fiat',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Ethereum World News',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/ethereumworldnews.png'}},
#  {'id': '26004305',
#   'guid': 'https://dailyhodl.com/?p=121478',
#   'published_on': 1607860847,
#   'imageurl': 'https://images.cryptocompare.com/news/dailyhodl/8vdv3pMycu3.jpeg',
#   'title': 'Michael Saylor Explains How Bitcoin Could Surge 80x and Beyond',
#   'url': 'https://dailyhodl.com/2020/12/13/michael-saylor-explains-how-bitcoin-could-surge-10x-to-100x/',
#   'source': 'dailyhodl',
#   'body': 'Michael Saylor, the chief executive of the world&#8217;s largest publicly traded business intelligence firm, is revealing how Bitcoin could\xa0meteorically rise by 100x from its current valuation. On a fireside chat with Binance founder Changpeng Zhao, the MicroStrategy head says Bitcoin needs to transform its old narrative of being a volatile, speculative asset suitable for investing [&#8230;]The post Michael Saylor Explains How Bitcoin Could Surge 80x and Beyond appeared first on The Daily Hodl.',
#   'tags': 'Bitcoin|BTC|News',
#   'categories': 'BTC|Exchange|Business',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'The Daily Hodl',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/dailyhodl.png'}},
#  {'id': '26004334',
#   'guid': 'https://cryptonews.com/exclusives/bitcoin-ethereum-xrp-bitcoin-cash-litecoin-chainlink-price-p-8604.htm',
#   'published_on': 1607860800,
#   'imageurl': 'https://images.cryptocompare.com/news/cryptonews/cPceoMP6jcP.png',
#   'title': 'Bitcoin, Ethereum, XRP, Bitcoin Cash, Litecoin, Chainlink Price Predictions for 2021',
#   'url': 'https://cryptonews.com/exclusives/bitcoin-ethereum-xrp-bitcoin-cash-litecoin-chainlink-price-p-8604.htm',
#   'source': 'cryptonews',
#   'body': '2020 may be a hard act to follow for the cryptoasset market. Beginning on January 1 with a total market capitalization of around USD 190bn, the entire market has grown over USD 560bn in December. This increase has unsurprisingly been paralleled by the performances of individual cryptoassets, with bitcoin (BTC) rising around 150% over the same time frame, and with',
#   'tags': 'Features',
#   'categories': 'Market|ETH|LTC|XRP|Trading',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'cryptonews',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cryptonews.png'}},
#  {'id': '26003744',
#   'guid': 'https://coingape.com/?p=77657',
#   'published_on': 1607859491,
#   'imageurl': 'https://images.cryptocompare.com/news/coingape/dbAwN0Mw020.png',
#   'title': 'Weekly Round-Up: Bitcoin (BTC) & Ethereum (ETH) Enter Recovery, XRP Drags Further Losses',
#   'url': 'https://coingape.com/weekly-round-up-what-all-happened-in-bitcoin-btc-ethereum-eth-and-xrp/',
#   'source': 'coingape',
#   'body': 'The last week in the crypto market remained a bit exciting, not in terms of the market movement but in terms of institutional developments happening in the cryptosphere. The overall cryptocurrency market remained under pressure while losing around $25 billion of the market cap. The top three cryptocurrencies: Bitcoin (BTC), Ethereum (ETH), and Ripple (XRP) The post Weekly Round-Up: Bitcoin (BTC) &amp; Ethereum (ETH) Enter Recovery, XRP Drags Further Losses appeared first on Coingape.',
#   'tags': 'Altcoin News|Bitcoin News|News|Bitcoin Price Recovery|Bitcoin vs gold|BTCBRL|BTCBUSD|BTCDAI|BTCEUR|BTCGBP|BTCJPY|BTCKRW|BTCMXN|BTCNGN|BTCPAX|BTCRUB|BTCTRY|BTCTUSD|BTCUSD|BTCUSDC|BTCUSDT|BTCXRP|BTCZAR|ETHAUD|ETHBKRW|ETHBRL|ETHBTC|ETHBUSD|ETHDAI|ETHEOSDT|Ethereum Price recovery|ETHEUR|ETHGBP|ETHHUSD|ETHJPY|ETHKRW|ETHMXN|ETHPAX|ETHRUB|ETHTRX|ETHTRY|ETHUSD|ETHUSDC|ETHUSDT|ETHUST|ETHZAR|Fidelity Digital Assets|JPMorgan|Ray Dalio|XRPAUD|XRPBNB|XRPBRL|XRPBTC|XRPCAD|XRPETH|XRPEUR|XRPGBP|XRPKRW|XRPMXN|XRPNGN|XRPPAX|XRPRUB|XRPTRX|XRPTRY|XRPTUSD|xrpusd|XRPUSDC|XRPUSDT',
#   'categories': 'BTC|ETH|XRP|Market',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'CoinGape',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/coingape.png'}},
#  {'id': '26003731',
#   'guid': 'https://cryptopotato.com/?p=94444',
#   'published_on': 1607859441,
#   'imageurl': 'https://images.cryptocompare.com/news/cryptopotato/aW000000000.png',
#   'title': 'Bitcoin Price Analysis: BTC Facing Critical Resistance At $19,400',
#   'url': 'https://cryptopotato.com/bitcoin-price-analysis-btc-facing-critical-resistance-at-19400/',
#   'source': 'cryptopotato',
#   'body': 'Bitcoin has successfully bucked the bearish trend that&#8217;s been suppressing prices for the past 10 days, following a strong bullish RSI divergence breakout that we predicted in the previous analysis. After briefly dipping underneath the 200-MA on the 4-hour chart for the first time in over 60 days, strong buying momentum returned behind the asset [&#8230;]',
#   'tags': 'BTC Analysis|BTCEUR|BTCGBP|BTCUSD|BTCUSDT|Crypto News|Bitcoin (BTC) Price',
#   'categories': 'BTC|Market|Trading',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Crypto Potato',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cryptopotato.png'}},
#  {'id': '26003338',
#   'guid': 'https://cointelegraph.com/news/bringing-digitalization-to-the-business-world-a-dlt-adoption-outlook',
#   'published_on': 1607858040,
#   'imageurl': 'https://images.cryptocompare.com/news/cointelegraph/dgE00000000.jpeg',
#   'title': 'Bringing digitalization to the business world: A DLT adoption outlook',
#   'url': 'https://cointelegraph.com/news/bringing-digitalization-to-the-business-world-a-dlt-adoption-outlook',
#   'source': 'cointelegraph',
#   'body': 'More companies are looking toward DLT to enhance business operations. Here is what the adoption landscape looks like.',
#   'tags': 'DLT|Adoption|Supply Chain',
#   'categories': 'Business',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'CoinTelegraph',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cointelegraph.png'}},
#  {'id': '26003000',
#   'guid': 'https://news.bitcoin.com/?p=428294&preview=true&preview_id=428294',
#   'published_on': 1607857253,
#   'imageurl': 'https://images.cryptocompare.com/news/bitcoin.com/eP0bg1Epw02.jpeg',
#   'title': 'Coinsbee Lets You Buy Gift Cards for More Than 500 Brands With Crypto',
#   'url': 'https://news.bitcoin.com/coinsbee-lets-you-buy-gift-cards-for-more-than-500-brands-with-crypto/',
#   'source': 'bitcoin.com',
#   'body': 'Coinsbee is a platform for buying gift cards with more than 50 cryptos from all your favorite brands and shops, as well as get payment cards and phone top-ups. You can use it to purchase vouchers for video game stores such as Steam and PlayStation, and even the video streaming giant Netflix. With the holidays [&#8230;]The post Coinsbee Lets You Buy Gift Cards for More Than 500 Brands With Crypto appeared first on Bitcoin News.',
#   'tags': 'Sponsored|Bitcoin|Coinsbee|Crypto|Cryptocurrency|Gift Cards|Netflix|PlayStation|Steam',
#   'categories': 'BTC|Sponsored',
#   'upvotes': '0',
#   'downvotes': '1',
#   'lang': 'EN',
#   'source_info': {'name': 'Bitcoin.com',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/bitcoincom.png'}},
#  {'id': '26003013',
#   'guid': 'http://ambcrypto.com/?p=131112',
#   'published_on': 1607857210,
#   'imageurl': 'https://images.cryptocompare.com/news/ambcrypto/c8sdgKwc8z0.jpeg',
#   'title': 'Tezos, BAT, Dogecoin Price Analysis: 13 December',
#   'url': 'https://ambcrypto.com/tezos-bat-dogecoin-price-analysis-13-december/',
#   'source': 'ambcrypto',
#   'body': 'Tezos has recorded losses over the past couple of weeks and it was heading back towards the $2-level of support, at the time of writing. Basic Attention Token was also on a downtrend since early-December and found support at the $0.2-level. Finally, Dogecoin was consolidating at its level of resistance. Tezos [XTZ] Tezos had bearish [&#8230;]',
#   'tags': 'Altcoins|Analysis|HideCryptopanic|News 1|Social|Trading View|BAT|DOGE|tezos',
#   'categories': 'Market|Trading|XTZ|ICO|Altcoin',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'AMB Crypto',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/ambcrypto.png'}},
#  {'id': '26002404',
#   'guid': 'http://ambcrypto.com/?p=131129',
#   'published_on': 1607855436,
#   'imageurl': 'https://images.cryptocompare.com/news/ambcrypto/c85qzhEoa61.jpeg',
#   'title': 'Cardano initiates Hard Fork to introduce Token Locking',
#   'url': 'https://ambcrypto.com/cardano-hard-fork-token-locking/',
#   'source': 'ambcrypto',
#   'body': 'A hard fork was initiated on the Cardano network a few hours ago, one that has largely gone unnoticed, presumably due to the way in which it was executed. The hard fork was initiated to introduce the token locking mechanism to the Cardano blockchain and the complete transition will now take place on 16 December [&#8230;]',
#   'tags': 'Altcoins|News 1|Social|Trading View|ADA|Cardano|Charles Hoskinson',
#   'categories': 'ADA|ICO|Blockchain|Altcoin',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'AMB Crypto',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/ambcrypto.png'}},
#  {'id': '26001227',
#   'guid': 'https://dailyhodl.com/?p=121554',
#   'published_on': 1607851766,
#   'imageurl': 'https://images.cryptocompare.com/news/dailyhodl/8ijIj1N69y2.jpeg',
#   'title': 'Sweden Considering Widescale Transition to Digital Currency: Report',
#   'url': 'https://dailyhodl.com/2020/12/13/sweden-considering-widescale-transition-to-digital-currency-report/',
#   'source': 'dailyhodl',
#   'body': 'Sweden, the world&#8217;s most cashless society, is now considering taking a leap into the world of digital currencies. According to a Bloomberg report, Sweden&#8217;s minister for financial markets Per Bolund announced that a study exploring the prospects of the country using digital currency is underway and it will likely be completed in November 2022. Bolund [&#8230;]The post Sweden Considering Widescale Transition to Digital Currency: Report appeared first on The Daily Hodl.',
#   'tags': 'Blockchain|Regulators|blockchain|News|regulators',
#   'categories': 'Blockchain|Market',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'The Daily Hodl',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/dailyhodl.png'}},
#  {'id': '26000598',
#   'guid': 'https://news.bitcoin.com/?p=428744',
#   'published_on': 1607850030,
#   'imageurl': 'https://images.cryptocompare.com/news/bitcoin.com/eEKi82k0w40.jpeg',
#   'title': 'Survey: 1 in 4 Senior Executives in Uruguay Have Used Cryptocurrencies',
#   'url': 'https://news.bitcoin.com/survey-1-in-4-senior-executives-in-uruguay-have-used-cryptocurrencies/',
#   'source': 'bitcoin.com',
#   'body': 'A survey made in Uruguay across different business sectors revealed that 24% of the 49 senior executives (1 in 4) from companies in the country claimed to have used cryptocurrencies at any point in their lives. Senior Executives in Uruguay Reveal Their Level of Knowledge on Cryptocurrencies According to the consulting firm Price Waterhouse Cooper, [&#8230;]The post Survey: 1 in 4 Senior Executives in Uruguay Have Used Cryptocurrencies appeared first on Bitcoin News.',
#   'tags': 'Finance|Bitcoin education|Blockchain|blockchain education|Crypto Adoption|Crypto education|Cryptocurrencies|Latin America|Stablecoins|Uruguay',
#   'categories': 'BTC|Blockchain|Trading|Business',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Bitcoin.com',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/bitcoincom.png'}},
#  {'id': '25999853',
#   'guid': 'https://cryptonews.com/news/bitcoin-rallies-above-usd-19k-again-xrp-dumps-8603.htm',
#   'published_on': 1607847788,
#   'imageurl': 'https://images.cryptocompare.com/news/cryptonews/80ZflX9$05w.jpeg',
#   'title': 'Bitcoin Rallies Above USD 19K Again, XRP Dumps',
#   'url': 'https://cryptonews.com/news/bitcoin-rallies-above-usd-19k-again-xrp-dumps-8603.htm',
#   'source': 'cryptonews',
#   'body': 'It took less than a week for the most popular cryptocurrency, bitcoin (BTC), to return above the USD 19,000 level after it was trading close to USD 17,600 this past Friday. Meanwhile, one of the recent best performing major coins, XRP, is the only top 10 token in red today.At the time of writing, BTC trades at USD 19,278 and is up by 4.5% in a day, erasing all its weekly',
#   'tags': 'Bitcoin News',
#   'categories': 'BTC|XRP|ICO|Trading',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'cryptonews',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cryptonews.png'}},
#  {'id': '25999474',
#   'guid': 'https://cryptopotato.com/?p=94425',
#   'published_on': 1607846792,
#   'imageurl': 'https://images.cryptocompare.com/news/cryptopotato/agNcF8gikM1.jpeg',
#   'title': 'Bitcoin Soars $1700 In 48-Hours: Trading Over $19K As Market Cap Gains $20B (Market Watch)',
#   'url': 'https://cryptopotato.com/bitcoin-soars-1700-in-48-hours-trading-over-19k-as-market-cap-gains-20b-market-watch/',
#   'source': 'cryptopotato',
#   'body': 'Crypto market cap eyes $560 billion as Bitcoin reclaimed $19K once again. Altcoins? most lack behind dues to the rising BTC dominance',
#   'tags': 'ADABTC|ADAUSD|BCHBTC|BCHUSD|BNBBTC|BNBUSD|BTCEUR|BTCGBP|BTCUSD|BTCUSDT|Crypto News|DOTBTC|DOTUSD|DOTUSDT|ETHBTC|ETHUSD|featured1|LINKBTC|LINKUSD|LTCBTC|LTCUSD|Market Updates|social|XRPBTC|XRPUSD|Bitcoin (BTC) Price|Ethereum (ETH) Price|Ripple (XRP) Price|Total Market Cap',
#   'categories': 'BTC|Market|Trading|Altcoin',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Crypto Potato',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cryptopotato.png'}},
#  {'id': '25999531',
#   'guid': 'https://cointelegraph.com/news/did-bitcoin-just-bottom-btc-reclaims-19k-as-new-rally-gains-steam',
#   'published_on': 1607846789,
#   'imageurl': 'https://images.cryptocompare.com/news/cointelegraph/c8kqgah0U80.jpeg',
#   'title': 'Did Bitcoin just bottom? BTC reclaims $19K as new rally gains steam',
#   'url': 'https://cointelegraph.com/news/did-bitcoin-just-bottom-btc-reclaims-19k-as-new-rally-gains-steam',
#   'source': 'cointelegraph',
#   'body': 'Bitcoin surpassed $19,000 after bottoming out at $17,600 as traders anticipate a broader BTC rally.',
#   'tags': 'bitcoin|bitcoin price',
#   'categories': 'BTC|Trading',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'CoinTelegraph',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cointelegraph.png'}},
#  {'id': '25999600',
#   'guid': 'https://dailyhodl.com/?p=121549',
#   'published_on': 1607846672,
#   'imageurl': 'https://images.cryptocompare.com/news/dailyhodl/elR6IVM6wMi.jpeg',
#   'title': 'These 5 Altcoins Are Poised for Massive Rallies in Q1 2021, Says Popular Crypto Trader',
#   'url': 'https://dailyhodl.com/2020/12/13/these-5-altcoins-are-poised-for-massive-rallies-in-q1-2021-says-popular-crypto-trader/',
#   'source': 'dailyhodl',
#   'body': 'Prominent crypto influencer and trader Tyler Swope is naming five altcoins that he says are set to erupt in the first quarter of 2021. In a new installment of Chico Crypto, Swope tells his 160,000 YouTube subscribers that he&#8217;s keeping a close eye on projects that tie back to the Polkadot (DOT) ecosystem and Polkadot [&#8230;]The post These 5 Altcoins Are Poised for Massive Rallies in Q1 2021, Says Popular Crypto Trader appeared first on The Daily Hodl.',
#   'tags': 'Altcoins|altcoins|News',
#   'categories': 'Altcoin',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'The Daily Hodl',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/dailyhodl.png'}},
#  {'id': '25999373',
#   'guid': 'http://ambcrypto.com/?p=131097',
#   'published_on': 1607846438,
#   'imageurl': 'https://images.cryptocompare.com/news/ambcrypto/e0a220800i0.jpeg',
#   'title': 'Chainlink, Synthetix, Status Price Analysis: 13 December',
#   'url': 'https://ambcrypto.com/chainlink-synthetix-status-price-analysis-13-december/',
#   'source': 'ambcrypto',
#   'body': 'Chainlink sat atop an important level of support, the loss of which would confirm that the market&#8217;s bears were in the driving seat in the LINK market. Synthetix registered a notable lack of buying volume in recent weeks, and it could continue its descent past $4.2. Finally, Status formed a bullish pattern and could see [&#8230;]',
#   'tags': 'Altcoins|Analysis|HideCryptopanic|News 1|Social|Trading View|LINK|SNT|SNX',
#   'categories': 'Market|Trading|Altcoin',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'AMB Crypto',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/ambcrypto.png'}},
#  {'id': '25997511',
#   'guid': 'https://www.newsbtc.com/?p=452113',
#   'published_on': 1607840923,
#   'imageurl': 'https://images.cryptocompare.com/news/newsbtc/bwNg40038w0.jpeg',
#   'title': 'Ethereum (ETH) is About to See “Liftoff” if It Closes Above $580',
#   'url': 'https://www.newsbtc.com/analysis/eth/ethereum-eth-liftoff-above-580/',
#   'source': 'newsbtc',
#   'body': 'Ethereum is recovering higher from the $535 support zone against the US Dollar. ETH price must surpass $580 to start a strong rally towards $600 and $620 in the near term. ETH price found support near $535 and started a steady recovery against the US Dollar. The price is currently trading above $560 and the [&#8230;]',
#   'tags': 'ETH|ethereum|ethusd|ETHUSDT',
#   'categories': 'ETH|Trading|Fiat',
#   'upvotes': '2',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'NewsBTC',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/newsbtc.png'}},
#  {'id': '25996894',
#   'guid': 'https://news.bitcoin.com/?p=428929',
#   'published_on': 1607839210,
#   'imageurl': 'https://images.cryptocompare.com/news/bitcoin.com/cVCM42001yc.jpeg',
#   'title': 'Popular Browsers Like Google Fail to Catch Copycat Crypto Sites, Scams Make the Top Results',
#   'url': 'https://news.bitcoin.com/popular-browsers-like-google-fail-to-catch-copycat-crypto-sites-scams-make-the-top-results/',
#   'source': 'bitcoin.com',
#   'body': 'As the digital asset economy grows popular and a number of crypto companies become well known, copycat scammers appear in greater numbers. There are a number of websites that are clones of the official web page from companies that provide mining device sales, wallets, full nodes, paper wallet tools, and popular trading platforms. Just recently, [&#8230;]The post Popular Browsers Like Google Fail to Catch Copycat Crypto Sites, Scams Make the Top Results appeared first on Bitcoin News.',
#   'tags': 'Security|bing|Bitcoin|Blockchain.com|BTC|Coinbase|Crypto Sites|Cryptocurrency|Exchanges|fake paper wallet generator|Fake Strongu Website|Fake Web Pages|Google|Google Results|Google search|security measures|Security Precautions|Spoof Pages|Trezor|Trezor Spoof app|Typosquatting|Wallets',
#   'categories': 'BTC|Mining|Trading|Wallet',
#   'upvotes': '1',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Bitcoin.com',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/bitcoincom.png'}},
#  {'id': '25994765',
#   'guid': 'https://cryptopotato.com/?p=94405',
#   'published_on': 1607832897,
#   'imageurl': 'https://images.cryptocompare.com/news/cryptopotato/ex0A0000200.jpeg',
#   'title': 'Grayscale Purchases More Than $74 Million for its Ethereum Trust',
#   'url': 'https://cryptopotato.com/grayscale-reports-major-eth-purchase-ethereum-trust/',
#   'source': 'cryptopotato',
#   'body': 'Grayscale announced the purchase of more than $74 million in ETH tokens for its one-of-a-kind SEC-registered way to invest in Ethereum',
#   'tags': 'AA News|Crypto News|ETHBTC|ETHUSD|ETH|Ethereum|Grayscale|SEC',
#   'categories': 'ETH|ICO|Regulation',
#   'upvotes': '2',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Crypto Potato',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cryptopotato.png'}},
#  {'id': '25994602',
#   'guid': 'https://www.newsbtc.com/?p=452109',
#   'published_on': 1607832521,
#   'imageurl': 'https://images.cryptocompare.com/news/newsbtc/e0wB21w0w0g.jpeg',
#   'title': 'Why Bitcoin Price Looks Ready For Another Leg Over $19,500',
#   'url': 'https://www.newsbtc.com/analysis/btc/bitcoin-price-another-leg-over-19500/',
#   'source': 'newsbtc',
#   'body': 'Bitcoin price started a steady upward move from the $17,500 support zone against the US Dollar. BTC is currently attempting an upside break and it could rally above $19,000. Bitcoin is trading in a positive zone above the $18,500 and $18,200 support levels. The price is now facing hurdles near the $19,000 level, but it [&#8230;]',
#   'tags': 'BTC|bitcoin|btcusd|BTCUSDT|xbtusd',
#   'categories': 'BTC|Trading|Fiat',
#   'upvotes': '1',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'NewsBTC',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/newsbtc.png'}},
#  {'id': '25993145',
#   'guid': 'https://news.bitcoin.com/?p=428862&preview=true&preview_id=428862',
#   'published_on': 1607828147,
#   'imageurl': 'https://images.cryptocompare.com/news/bitcoin.com/aMcP1Oscb1y.jpeg',
#   'title': 'Crypto Founder Faces 10 Years in Prison Over Millions of Dollars in Exit Scam Without Paying Taxes',
#   'url': 'https://news.bitcoin.com/cryptocurrency-founder-years-prison-millions-dollars-exit-scam-without-paying-taxes/',
#   'source': 'bitcoin.com',
#   'body': 'A cryptocurrency founder has been arrested and is facing up to 10 years imprisonment for tax evasion after running an exit scam. He allegedly made millions of dollars from his cryptocurrency and used an elaborate scheme to avoid paying taxes. Crypto Founder Exit Scams, Caught for Tax Evasion The U.S. Department of Justice (DOJ) announced [&#8230;]The post Crypto Founder Faces 10 Years in Prison Over Millions of Dollars in Exit Scam Without Paying Taxes appeared first on Bitcoin News.',
#   'tags': 'Regulation|crypto exit scam|crypto scam|crypto scammer|Exit Scam|oyster pearl|tax evasion',
#   'categories': 'Regulation|BTC',
#   'upvotes': '1',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Bitcoin.com',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/bitcoincom.png'}},
#  {'id': '25992304',
#   'guid': 'https://www.newsbtc.com/?p=452107',
#   'published_on': 1607825711,
#   'imageurl': 'https://images.cryptocompare.com/news/newsbtc/e1BOw0000w0.jpeg',
#   'title': 'SushiSwap’s SUSHI Bounces 10% as Crypto Market Recovers',
#   'url': 'https://www.newsbtc.com/analysis/defi-coins/sushiswaps-sushi-bounces-10-as-crypto-market-recovers/',
#   'source': 'newsbtc',
#   'body': 'SushiSwap (SUSHI) incurred a strong drop this past week, falling alongside Bitcoin, Ethereum, and the rest of the DeFi market. The price of the leading cryptocurrency fell from its multi-month highs near $2.50 to $1.95 in a strong move lower. This move was much more rapid and deep than drops in other cryptocurrencies. But quickly, [&#8230;]',
#   'tags': 'DeFi|sushi|SushiSwap',
#   'categories': 'Market|BTC|ETH|Trading',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'NewsBTC',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/newsbtc.png'}},
#  {'id': '25989782',
#   'guid': 'https://cointelegraph.com/news/origin-dollar-compensation-plan-marks-progressing-maturation-of-defi-space',
#   'published_on': 1607817961,
#   'imageurl': 'https://images.cryptocompare.com/news/cointelegraph/cgeQ3Tw_wmY.jpeg',
#   'title': 'Origin Dollar compensation plan marks progressing maturation of DeFi space',
#   'url': 'https://cointelegraph.com/news/origin-dollar-compensation-plan-marks-progressing-maturation-of-defi-space',
#   'source': 'cointelegraph',
#   'body': 'Traders and developers are trending towards greater DeFi depositor protections in unison',
#   'tags': 'Insurance|Cover|NSURE|COVER|DeFi|Hack|Exploit',
#   'categories': 'Fiat',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'CoinTelegraph',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cointelegraph.png'}},
#  {'id': '25989613',
#   'guid': 'https://www.newsbtc.com/?p=452102',
#   'published_on': 1607817593,
#   'imageurl': 'https://images.cryptocompare.com/news/newsbtc/eH04006fz00.jpeg',
#   'title': 'IPO Windfalls from Airbnb Could Boost Bitcoin: DCG CEO',
#   'url': 'https://www.newsbtc.com/analysis/btc/ipo-windfalls-from-airbnb-could-boost-bitcoin-dcg-ceo/',
#   'source': 'newsbtc',
#   'body': 'Aside from MicroStrategy raising $650 million for Bitcoin this past week, one of the biggest news on financial Twitter was the Airbnb IPO. After months and even years of anticipation, the global peer-to-peer rental service went public on the stock market. While this came in the middle of a pandemic when the firm&#8217;s profits are [&#8230;]',
#   'tags': 'BTC|btcusd|BTCUSDT|xbtusd',
#   'categories': 'BTC|Market|Business',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'NewsBTC',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/newsbtc.png'}},
#  {'id': '25988735',
#   'guid': 'https://news.bitcoin.com/?p=428857&preview=true&preview_id=428857',
#   'published_on': 1607814939,
#   'imageurl': 'https://images.cryptocompare.com/news/bitcoin.com/e2o842882c0.jpeg',
#   'title': 'Morgan Stanley Strategist: Bitcoin Rising to Replace US Dollar as World’s Reserve Currency',
#   'url': 'https://news.bitcoin.com/morgan-stanley-strategist-bitcoin-replace-us-dollar-worlds-reserve-currency/',
#   'source': 'bitcoin.com',
#   'body': 'Morgan Stanley&#8217;s global strategist has made a case that bitcoin is making progress towards replacing the U.S. dollar as the world&#8217;s reserve currency. &#8220;Do not assume that your traditional currencies are the only stores of value, or mediums of exchange, that people will ever trust,&#8221; he warned governments. Bitcoin Is on Its Way to Becoming [&#8230;]The post Morgan Stanley Strategist: Bitcoin Rising to Replace US Dollar as World&#8217;s Reserve Currency appeared first on Bitcoin News.',
#   'tags': "Economics|Bitcoin regulation|bitcoin replaces USD|bitcoin replacing US dollar|bitcoin world's reserve currency|Money Printing|morgan stanley bitcoin|morgan stanley crypto|morgan stanley cryptocurrency",
#   'categories': 'Fiat|BTC|Exchange',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Bitcoin.com',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/bitcoincom.png'}},
#  {'id': '25988398',
#   'guid': 'https://www.newsbtc.com/?p=452097',
#   'published_on': 1607814054,
#   'imageurl': 'https://images.cryptocompare.com/news/newsbtc/c0020000000.jpeg',
#   'title': 'XRP Tanks Following Hyped Airdrop That Catalyzed Parabolic Rally',
#   'url': 'https://www.newsbtc.com/analysis/xrp/xrp-tanks-following-hyped-airdrop-that-catalyzed-parabolic-rally/',
#   'source': 'newsbtc',
#   'body': 'XRP has given up a serious percentage of its recent gains, with the cryptocurrency&#8217;s parabolic rally fading and showing few signs of strength as sellers rise with full force. The cryptocurrency&#8217;s parabolic rally came about shortly after it plunged to lows of $0.23 before rallying to the top of its multi-year trading range around $0.30. [&#8230;]',
#   'tags': 'XRP|XRPBTC|XRPUSD|xrpusdt',
#   'categories': 'Trading|XRP',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'NewsBTC',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/newsbtc.png'}},
#  {'id': '25988296',
#   'guid': 'https://www.cryptopolitan.com/?p=74518',
#   'published_on': 1607813695,
#   'imageurl': 'https://images.cryptocompare.com/news/cryptopolitan/aw000000000.png',
#   'title': 'Stellar Lumens price holds $0.150 support, price to recover to the $0.200 level',
#   'url': 'https://www.cryptopolitan.com/stellar-lumens-price-0-150-recovery-ahead/',
#   'source': 'cryptopolitan',
#   'body': 'TL;DR Breakdown Stellar Lumens price $ 0.160772 at the time of writing Price shows significant bullish momentum. Price expected to make a smooth recovery to $0.200 level Stellar Lumens (XLM) price is enjoying bullish momentum today as the price bounces back from the $0.150 support level. The bearish pressure on the asset has decreased considerably […]',
#   'tags': 'Altcoin News|cryptocurrency trading|cryptomarket',
#   'categories': 'Trading',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'Cryptopolitan',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/cryptopolitan.png'}},
#  {'id': '25987931',
#   'guid': 'https://zycrypto.com/?p=47331',
#   'published_on': 1607812556,
#   'imageurl': 'https://images.cryptocompare.com/news/zycrypto/c20000g0000.jpeg',
#   'title': 'XRP Price Dips By 10% Following Spark Airdrop While Bitcoin Surges Towards $19,000',
#   'url': 'https://zycrypto.com/xrp-price-dips-by-10-following-spark-airdrop-while-bitcoin-surges-towards-19000/',
#   'source': 'zycrypto',
#   'body': 'It seems that XRP has experienced a classic case of ‘buy the rumors, sell the news’ event where investors jumped into the digital asset thanks to the Spark airdrop but quickly sold their gains after the event ended. Ripple&#8217;s XRP price is down by around 10% today from a high point of $0.55 to a [&#8230;]',
#   'tags': 'Cryptocurrency|Markets|News|Bitcoin News|BTCUSD|BTCUSDC|BTCUSDT|XRP News|XRPUSD|XRPUSDT',
#   'categories': 'XRP|Trading|BTC|Market|Business',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'ZyCrypto',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/zycrypto.png'}},
#  {'id': '25987566',
#   'guid': 'https://dailyhodl.com/?p=121309',
#   'published_on': 1607811314,
#   'imageurl': 'https://images.cryptocompare.com/news/dailyhodl/cFIEo0ww000.jpeg',
#   'title': 'Investment Icon Ric Edelman Owns Bitcoin and Ethereum, Says XRP Is Part of Technological Revolution',
#   'url': 'https://dailyhodl.com/2020/12/12/investment-icon-ric-edelman-owns-bitcoin-and-ethereum-says-xrp-is-part-of-technological-revolution/',
#   'source': 'dailyhodl',
#   'body': 'Investment icon Ric Edelman, named the nation&#8217;s top independent financial advisor by Barron&#8217;s three times over, says he&#8217;s a believer and investor in cryptocurrency. In a new interview with Real Vision, the founder of Edelman Financial Engines, which has more than $200 billion in assets under management, says he first began to tinker with crypto [&#8230;]The post Investment Icon Ric Edelman Owns Bitcoin and Ethereum, Says XRP Is Part of Technological Revolution appeared first on The Daily Hodl.',
#   'tags': 'Altcoins|Bitcoin|BTC|ETH|Ethereum|News|XRP',
#   'categories': 'BTC|ETH|XRP|Altcoin|Business',
#   'upvotes': '0',
#   'downvotes': '0',
#   'lang': 'EN',
#   'source_info': {'name': 'The Daily Hodl',
#    'lang': 'EN',
#    'img': 'https://images.cryptocompare.com/news/default/dailyhodl.png'}}]

# %%
for news in result['Data']:
    print(news['title'])
# Out:
# Host of CNBC’s ‘Mad Money’ Explains Why He Invested in Bitcoin
# New withdrawal mechanism for ETH2 stakes ‘under discussion’
# Today Marks 10 Years Since Satoshi Nakamoto’s Last Public Activity
# XRP’s Price Steadies After Crash That Followed Huge Airdrop
# Publicly recanted! Luminaries who came to terms with crypto in 2020
# Bitcoin: Retail v. whale traders and who profited the most?
# The 10 Year Anniversary of Bitcoin Creator’s Disappearance
# Buy Bitcoin, Robert Kiyosaki urges
# India Surpasses China in Peer to Peer Bitcoin Volumes
# 10.7% of Ethereum 2.0 Validator Deposits are From Kraken
# How Much Debt Can a Country Handle?
# Bitcoin Up 9.85% Since Friday, ‘Rich Dad Author’ Says ‘Buy Below $20 K’
# PlanB Says Bitcoin Entering Enormous Bull Year in 2021, Outlines Price Targets and Biggest Risk to BTC
# Bitcoin Gains Popularity Among The Rich As Bull Market Rages On
# Room For Growth? Only 10% of UK Citizens Have Purchased Bitcoin
# Bitcoin price suddenly regains bullish momentum with $20K in sight
# Former Goldman Sachs Exec on Muti-Trillion Dollar Opportunities for Crypto
# Bitcoin SV, IOTA, Nano Price Analysis: 13 December
# DeFi Could Break $20B in Total Value Locked before EOY – Report
# Bitcoin price analysis: 13 December
# Ledger Wallet Customer Data Leak Invokes Threats, Phishing Scams, User Allegedly Loses Life Savings
# Buy Bitcoin (BTC) Below $20k – Rich Dad Poor Dad Author
# Michael Saylor Explains How Bitcoin Could Surge 80x and Beyond
# Bitcoin, Ethereum, XRP, Bitcoin Cash, Litecoin, Chainlink Price Predictions for 2021
# Weekly Round-Up: Bitcoin (BTC) & Ethereum (ETH) Enter Recovery, XRP Drags Further Losses
# Bitcoin Price Analysis: BTC Facing Critical Resistance At $19,400
# Bringing digitalization to the business world: A DLT adoption outlook
# Coinsbee Lets You Buy Gift Cards for More Than 500 Brands With Crypto
# Tezos, BAT, Dogecoin Price Analysis: 13 December
# Cardano initiates Hard Fork to introduce Token Locking
# Sweden Considering Widescale Transition to Digital Currency: Report
# Survey: 1 in 4 Senior Executives in Uruguay Have Used Cryptocurrencies
# Bitcoin Rallies Above USD 19K Again, XRP Dumps
# Bitcoin Soars $1700 In 48-Hours: Trading Over $19K As Market Cap Gains $20B (Market Watch)
# Did Bitcoin just bottom? BTC reclaims $19K as new rally gains steam
# These 5 Altcoins Are Poised for Massive Rallies in Q1 2021, Says Popular Crypto Trader
# Chainlink, Synthetix, Status Price Analysis: 13 December
# Ethereum (ETH) is About to See “Liftoff” if It Closes Above $580
# Popular Browsers Like Google Fail to Catch Copycat Crypto Sites, Scams Make the Top Results
# Grayscale Purchases More Than $74 Million for its Ethereum Trust
# Why Bitcoin Price Looks Ready For Another Leg Over $19,500
# Crypto Founder Faces 10 Years in Prison Over Millions of Dollars in Exit Scam Without Paying Taxes
# SushiSwap’s SUSHI Bounces 10% as Crypto Market Recovers
# Origin Dollar compensation plan marks progressing maturation of DeFi space
# IPO Windfalls from Airbnb Could Boost Bitcoin: DCG CEO
# Morgan Stanley Strategist: Bitcoin Rising to Replace US Dollar as World’s Reserve Currency
# XRP Tanks Following Hyped Airdrop That Catalyzed Parabolic Rally
# Stellar Lumens price holds $0.150 support, price to recover to the $0.200 level
# XRP Price Dips By 10% Following Spark Airdrop While Bitcoin Surges Towards $19,000
# Investment Icon Ric Edelman Owns Bitcoin and Ethereum, Says XRP Is Part of Technological Revolution
